# %% [markdown]
# # Ejercicio
#
# Crear un *programa* en **Python** en el que se grafique la función $f\left(x\right)=x^{2n}\sin\left(\pi x\right)$ para $n$ valores en el intervalo para $x\in\left(0,1\right)$

# %%
# Importar las librerias necesarias
import matplotlib.pyplot as plt
import numpy as np

# %%
# Definir la función a graficar
def funcion(x,n):
    return x**(2*n)*np.sin(np.pi*x)

# Crear el dominio de graficación
x = np.linspace(0,1,500)

# Crear un ciclo para graficar las primeras 10 funciones
for n in range(0, 30):
    
    # Evaluar la función
    y = funcion(n, x)

    # Graficar la función
    plt.plot(x,y)

# Configurar y Mostrar la gráfica
plt.grid(linestyle='--')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('Gráfica de la función $f\\left(x\\right)=x^{2n}\\sin\\left(\\pi x\\right)$ para los primeros valores de $n$')
plt.show()
